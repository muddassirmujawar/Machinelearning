# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
from sklearn.datasets import load_boston

# %%
x=load_boston()

# %%
df=pd.DataFrame(x.data,columns=x.feature_names)
df['MEDV']=x.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
x=df.iloc[:,0:13].values

# %%
x[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00])

# %%
y=df.iloc[:,13].values

# %%
y[0]
# Out:
# 24.0

# %%
import seaborn as sns

# %%
cor=df.corr()
sns.heatmap(cor, cmap='Blues', annot=True,)
plt.show()

# %%
cor_target=abs(cor['MEDV'])

# %%
cor_target
# Out:
# CRIM       0.388305
# ZN         0.360445
# INDUS      0.483725
# CHAS       0.175260
# NOX        0.427321
# RM         0.695360
# AGE        0.376955
# DIS        0.249929
# RAD        0.381626
# TAX        0.468536
# PTRATIO    0.507787
# B          0.333461
# LSTAT      0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
relevent_feature= cor_target[cor_target>0.5]

# %%
relevent_feature
# Out:
# RM         0.695360
# PTRATIO    0.507787
# LSTAT      0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
relevent_feature=relevent_feature[relevent_feature<1.0]

# %%
relevent_feature
# Out:
# RM         0.695360
# PTRATIO    0.507787
# LSTAT      0.737663
# Name: MEDV, dtype: float64

# %% [markdown]
# cor=df.corr()
# sns.heatmap(cor, cmap='Blues', annot=True,)
# plt.show()
# df=pd.DataFrame(x.data,columns=x.feature_names)
# df['MEDV']=x.target
# sns.heatmap(data[['f1', 'f4', 'f5', 'f6','f7','f8','f9','f10','target']].corr(), cmap='Blues', annot=True)

# %% [markdown]
# draw hewatmap for the relevent features

# %%
relevent_feature=[relevent_feature]
relevent_feature
# Out:
# [[RM         0.695360
#   PTRATIO    0.507787
#   LSTAT      0.737663
#   Name: MEDV, dtype: float64]]

# %%
sns.heatmap([relevent_feature].corr(),annot=True,cmap='Blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10016/3256768100.py in <module>
# ----> 1 sns.heatmap([relevent_feature].corr(),annot=True,cmap='Blue')
#
# AttributeError: 'list' object has no attribute 'corr'
