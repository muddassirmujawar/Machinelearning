# %%
import pandas as pd 
from sklearn import linear_model

# %%
values = pd.read_csv("df.csv")



# 

#
# #predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
# predictedCO2 = regr.predict([[2300, 1300]])

# print(predictedCO2)

# %%
values.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                f1  \
# 0           0             0  2020-12-31 09:46:17.463002+00:00
# 1           1             1  2020-12-31 09:46:17.463002+00:00
# 2           2             2  2020-12-31 09:46:17.463002+00:00
# 3           3             3  2020-12-31 09:46:17.463002+00:00
# 4           4             4  2020-12-31 09:46:18.191119+00:00
#
#                           f4                         f5  f6     f7    f8  f9  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True   0.0   0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True  32.0   1
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   1
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   2
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   1  False  20.0   0
#
#     f10
# 0   c-2
# 1   c-2
# 2   c-4
# 3   c-4
# 4  b-69

# %%
values =values.replace(to_replace ="True",
                  value ="0")
values.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                f1  \
# 0           0             0  2020-12-31 09:46:17.463002+00:00
# 1           1             1  2020-12-31 09:46:17.463002+00:00
# 2           2             2  2020-12-31 09:46:17.463002+00:00
# 3           3             3  2020-12-31 09:46:17.463002+00:00
# 4           4             4  2020-12-31 09:46:18.191119+00:00
#
#                           f4                         f5  f6     f7    f8  f9  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True   0.0   0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True  32.0   1
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   1
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   2
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   1  False  20.0   0
#
#     f10
# 0   c-2
# 1   c-2
# 2   c-4
# 3   c-4
# 4  b-69

# %%
# values=pd.to_numeric(values['f7'])

# %%
koutput=pd.read_csv("Y_train.csv")
koutput.head()
# Out:
#    Unnamed: 0   target
# 0           0   7400.0
# 1           1   8650.0
# 2           2   9150.0
# 3           3  10400.0
# 4           4   8697.0

# %%
df=pd.concat([values,koutput],axis=1)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                f1  \
# 0           0             0  2020-12-31 09:46:17.463002+00:00
# 1           1             1  2020-12-31 09:46:17.463002+00:00
# 2           2             2  2020-12-31 09:46:17.463002+00:00
# 3           3             3  2020-12-31 09:46:17.463002+00:00
# 4           4             4  2020-12-31 09:46:18.191119+00:00
#
#                           f4                         f5  f6     f7    f8  f9  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True   0.0   0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00   0   True  32.0   1
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   1
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00   0   True  32.0   2
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   1  False  20.0   0
#
#     f10  Unnamed: 0   target
# 0   c-2           0   7400.0
# 1   c-2           1   8650.0
# 2   c-4           2   9150.0
# ...

# %%
# df.info()
values = values[:1000]
#

# %%
# X =df['f1', 'f4','f5','f6','f8','f9','f10']
y = df['target']
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19416/2396917310.py in <module>
#       1 # X =df['f1', 'f4','f5','f6','f8','f9','f10']
# ----> 2 y = df['target']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3468             indexer = np.where(indexer)[0]
#    3469
# -> 3470         data = self._take_with_is_copy(indexer, axis=1)
#    3471
#    3472         if is_single_key:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ...

# %%
# X= df['f1','f4','f5','f6','f8','f9','f10']
df.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19416/302743284.py in <module>
#       1 # X= df['f1','f4','f5','f6','f8','f9','f10']
# ----> 2 df.astype('int64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
# ...
